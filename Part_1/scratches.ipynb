# %%
def func():
    a = 10
    return a

# %%
func
# Out:
# <function __main__.func()>

# %%
func()
# Out:
# 10

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def func():\n    a = 10\n    return a',
#   'func',
#   'func()',
#   'globals()'],
#  '_oh': {2: <function __main__.func()>, 3: 10},
#  '_dh': [PosixPath('/home/tjisana/dev/pythondeepdive/Part_1')],
#  'In': ['',
#   'def func():\n    a = 10\n    return a',
#   'func',
#   'func()',
#   'globals()'],
#  'Out': {2: <function __main__.func()>, 3: 10},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fe2fba32bf0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7fe2fba33310>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7fe2fba33310>,
#  '_': 10,
#  '__': <function __main__.func()>,
#  '___': '',
# ...

# %%
globals()['func']
# Out:
# <function __main__.func()>

# %%
import sys
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module '_frozen_importlib' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  '_io': <module '_io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'posix': <module 'posix' (built-in)>,
#  '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>,
#  'time': <module 'time' (built-in)>,
#  'zipimport': <module 'zipimport' (frozen)>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'codecs': <module 'codecs' from '/home/tjisana/.pyenv/versions/3.10.4/lib/python3.10/codecs.py'>,
#  'encodings.aliases': <module 'encodings.aliases' from '/home/tjisana/.pyenv/versions/3.10.4/lib/python3.10/encodings/aliases.py'>,
# ...
